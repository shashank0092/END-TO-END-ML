# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("./Iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df=df.drop("Id",axis=1)
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df.duplicated().sum()
# Out:
# 3

# %%
df.corr()
# Out:
# C:\Users\SHASHANK SHUKLA\AppData\Local\Temp\ipykernel_15844\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df['SepalLengthCm'].value_counts()
# Out:
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: SepalLengthCm, dtype: int64

# %%
df['SepalLengthCm'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot: >

# %%
df['SepalLengthCm'].max()
# Out:
# 7.9

# %%
df.value_counts("Species")
# Out:
# array([50, 50, 50], dtype=int64)

# %%
# plt.title("Number Of Species Avlaible")
plt.figure(figsize=(15,6))
sns.countplot(x='Species',data=df,width=0.5)
# Out:
# <AxesSubplot: xlabel='Species', ylabel='count'>

# %%
pie_values=df.value_counts("Species").values
print(pie_values)
pie_labels=df.value_counts("Species").index
# pie_labels=pd.DataFrame(pie_labels)
print(pie_labels)
# Out:
# [50 50 50]
# Index(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype='object', name='Species')

# %%
sizes=pie_values
lables=pie_labels

# %%
# plt.title("Pie Plot Of Types Of Spices")
plt.figure(figsize=(15,6))
plt.pie(sizes,labels=lables,autopct='%1.1f%%',startangle=90)
plt.show()

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
plt.figure(figsize=(15,6))
plt.title("Numric Distribution Of SepalLengthCm")
plt.xlabel("Values")
plt.ylabel("Number Of Values")
plt.hist(df['SepalLengthCm'],color="green")

plt.show()

# %%
plt.figure(figsize=(15,6))
plt.title("Numerical Distribution Of SepalWidthCm")
plt.xlabel("Values")
plt.ylabel("Number Of Values")
plt.hist(df['SepalWidthCm'],color="red")
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.title('Numeric Distribution of PetalLength')
plt.xlabel("Values")
plt.ylabel("Number Of Values")
plt.hist(df['PetalLengthCm'],color="Pink")
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.title("Numeric Distribution Of PetalWidth")
plt.xlabel("Values")
plt.ylabel("Number Of Values")
plt.hist(df['PetalWidthCm'],color="purple")
plt.show()

# %%
sns.displot(df["SepalLengthCm"],color="red",kde=True)
plt.title("Distplot of Septal Length")
plt.show()

# %%
sns.displot(df["SepalWidthCm"],color="blue",kde=True)
plt.title("Distplot of Septal Width")
plt.show()

# %%
sns.displot(df["PetalLengthCm"],color="green",kde=True)
plt.title("Distplot of Petal Length")
plt.show()

# %%
sns.displot(df["PetalWidthCm"],color="purple",kde=True)
plt.title("Distplot of Petal Width")
plt.show()

# %%
sns.boxplot(df["SepalLengthCm"],color="red")
plt.title("Outliers in Speal Lenght")
plt.show()

# %%
sns.boxplot(df["SepalWidthCm"],color="green")
plt.title("Outliers in Speal Width")
plt.show()

# %%
sns.boxplot(df["PetalLengthCm"],color="Pink")
plt.title("Outliers in Petal Lenght")
plt.show()

# %%
sns.boxplot(df["PetalWidthCm"],color="Purple")
plt.title("Outliers in Petal Width")
plt.show()

# %%
sns.scatterplot(x=df['SepalLengthCm'],y=df['SepalWidthCm'],hue=df["Species"])
plt.title("Relation Between Septal Length and Spetal Width")
plt.show()

# %%
sns.scatterplot(x=df['PetalLengthCm'],y=df['PetalWidthCm'],hue=df["Species"])
plt.title("Relation Between Petal Length and Petal Width")
plt.show()

# %%
sns.scatterplot(x=df['SepalLengthCm'],y=df['PetalLengthCm'],hue=df["Species"])
plt.title("Relation Between SepalLengthCm and PetalLengthCm")
plt.show()

# %%
sns.scatterplot(x=df['SepalWidthCm'],y=df['PetalWidthCm'],hue=df["Species"])
plt.title("Relation Between SepalWidthCm and Petal Width")
plt.show()

# %%
sns.pairplot(data=df,hue='Species')

# %%
sns.heatmap(df.corr(method="pearson"),annot=True)
plt.title("Heatmap of correlations")
plt.show()
# Out:
# C:\Users\SHASHANK SHUKLA\AppData\Local\Temp\ipykernel_15844\3521599620.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(method="pearson"),annot=True)
